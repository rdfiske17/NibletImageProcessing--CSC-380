# %% [markdown]
# # Convolutional Neural Networks using Tensorflow and Keras
#
# We will work through creating a convolutional neural network from scratch.

# %% [markdown]
# ## Step 1 - Import the data
#
# We will use `image_dataset_from_directory` to build our training and validation sets. This function expects our images to be in folders separated by class, and the classifcation values are inferred from the folder names.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# You can mess with batch size
BATCH_SIZE = 16
IMAGE_SIZE = (224,224)
SEED = 1

# This sets up a training and validation set from our ../data/ directory
train_dataset = tf.keras.utils.image_dataset_from_directory(
    '../data/',
    class_names = ['not_niblet','niblet'],
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    shuffle=True,
    validation_split=0.2,
    subset='training',
    seed=SEED)

# This is the validation set. Notice `shuffle = FALSE` and `subset = validation`
val_dataset = tf.keras.utils.image_dataset_from_directory(
    '../data/',
    class_names = ['not_niblet','niblet'],
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    shuffle=True,
    validation_split=0.2,
    subset='validation',
    seed=SEED)
# Out:
# Found 1729 files belonging to 2 classes.
# Using 1384 files for training.
# Found 1729 files belonging to 2 classes.
# Using 345 files for validation.

# %% [markdown]
# ## Step 2 - Set up the image augmentation and preprocessing
#
# This [tutorial](https://www.tensorflow.org/guide/keras/preprocessing_layers) provides some of the preprocessing and image augmentation option using Keras layers. We will be integrating the preprocessing and augmentation into our model, which streamlines the process and makes the model more portable. But the tutorial also presents an alternate way that may be more efficient if you are training using your CPU (which we are unless you do some extra setup to utilize a GPU).
#
# You can experiment with some of the other image augmentation layers such as:
# * tf.keras.layers.RandomCrop
# * tf.keras.layers.RandomFlip
# * tf.keras.layers.RandomTranslation
# * tf.keras.layers.RandomRotation
# * tf.keras.layers.RandomZoom
# * tf.keras.layers.RandomContrast
#
# We will also be applying some preprocessing to rescale the images to have color values in [0,1] instead of [0,255] and to crop/resize the images down to (224,224). We don't need the cropping for the images that we processed last class period, but this will allow us to use our model on any size image without worrying about processing it first.

# %%
from tensorflow.keras import layers

image_preprocess = tf.keras.Sequential([
    tf.keras.Input((None,None,3)),
    layers.Resizing(224,224, crop_to_aspect_ratio = True),
    layers.Rescaling(1./255),
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(.5,.2)#, #added RandomZoom, idk if this will really do anything
    #layers.RandomBrightness(0.0007), # also added the next three here
    #layers.RandomContrast(0.1),
    #layers.GaussianNoise(0.1)
])

image_preprocess.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing_2 (Resizing)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_2 (Rescaling)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip_2 (RandomFlip)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation_2               │ (None, 224, 224, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom_2 (RandomZoom)      │ (None, 224, 224, 3)    │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Test out our image augmentation:

# %%
iterator = iter(train_dataset)

plt.figure(figsize=(10, 10))
for i in range(9):
  image = tf.cast(tf.expand_dims(next(iterator)[0][0], 0), tf.float32)
  augmented_image = image_preprocess(image)
  #augmented_image = tf.clip_by_value(augmented_image, 0.0, 1.0) # Clip pixel values to the valid range [0, 1]
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(augmented_image[0])
  plt.axis("off")

plt.show()

# %% [markdown]
# ## Step 3 - Sequential Layers
#
# The main layers we will use are:
# * [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) - Convolutional layer
# * [AveragePooling2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/AveragePooling2D) or [MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D) - Pooling layers
# * [Flatten](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten) - After all the convolutions are done, this flattens the 2D image to a vector.
# * [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) - Fully connected layer
# * [Dropout](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) - Randomly masks a portion of the previous layer during training.
#
# You can experiment with the parameters in these layers.

# %%
# Dr. Tanner's Models

nnet_layers = tf.keras.Sequential([
    tf.keras.Input((224,224,3)),
    layers.Conv2D(filters = 4, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.Conv2D(filters = 8, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.Conv2D(filters = 32, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.Conv2D(filters = 64, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.Flatten(),
    layers.Dense(1024, activation = 'relu'),
    layers.Dropout(0.2),
    layers.Dense(64, activation = 'relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation = 'sigmoid')
])

nnet_layers.summary()

# My Models

# Model 2: AveragePooling2D instead of MaxPooling2D
nnet_layers2 = tf.keras.Sequential([
    tf.keras.Input((224,224,3)),
    layers.Conv2D(filters = 4, kernel_size = (3,3), activation = 'relu'),
    layers.AveragePooling2D(pool_size = (2,2)),
    layers.Conv2D(filters = 8, kernel_size = (3,3), activation = 'relu'),
    layers.AveragePooling2D(pool_size = (2,2)),
    layers.Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu'),
    layers.AveragePooling2D(pool_size = (2,2)),
    layers.Conv2D(filters = 32, kernel_size = (3,3), activation = 'relu'),
    layers.AveragePooling2D(pool_size = (2,2)),
    layers.Conv2D(filters = 64, kernel_size = (3,3), activation = 'relu'),
    layers.AveragePooling2D(pool_size = (2,2)),
    layers.Flatten(),
    layers.Dense(1024, activation = 'relu'),
    layers.Dropout(0.2),
    layers.Dense(64, activation = 'relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation = 'sigmoid')
])

nnet_layers2.summary()

from tensorflow.keras.layers import BatchNormalization, GlobalAveragePooling2D

# Model 3: adding normalization

nnet_layers3 = tf.keras.Sequential([
    tf.keras.Input((224,224,3)),
    layers.Conv2D(filters = 4, kernel_size = (3,3), activation = 'relu'),
    BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.Conv2D(filters = 8, kernel_size = (3,3), activation = 'relu'),
    BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu'),
    BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.Conv2D(filters = 32, kernel_size = (3,3), activation = 'relu'),
    BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.Conv2D(filters = 64, kernel_size = (3,3), activation = 'relu'),
    BatchNormalization(),
    layers.GlobalAveragePooling2D(),
    layers.Dense(1024, activation = 'relu'),
    layers.Dropout(0.2),
    layers.Dense(64, activation = 'relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation = "sigmoid")
])

nnet_layers3.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_30 (Conv2D)              │ (None, 222, 222, 4)    │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 111, 111, 4)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 109, 109, 8)    │           296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 54, 54, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 52, 52, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 26, 26, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 24, 24, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 10, 10, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 1024)           │     1,639,424 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 64)             │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,729,801 (6.60 MB)
#  Trainable params: 1,729,801 (6.60 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_35 (Conv2D)              │ (None, 222, 222, 4)    │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_10            │ (None, 111, 111, 4)    │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 109, 109, 8)    │           296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_11            │ (None, 54, 54, 8)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 52, 52, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_12            │ (None, 26, 26, 16)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 24, 24, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_13            │ (None, 12, 12, 32)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 10, 10, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_14            │ (None, 5, 5, 64)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 1024)           │     1,639,424 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,729,801 (6.60 MB)
#  Trainable params: 1,729,801 (6.60 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_40 (Conv2D)              │ (None, 222, 222, 4)    │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 222, 222, 4)    │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 111, 111, 4)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 109, 109, 8)    │           296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 109, 109, 8)    │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 54, 54, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_42 (Conv2D)              │ (None, 52, 52, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 52, 52, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_25 (MaxPooling2D) │ (None, 26, 26, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 24, 24, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 24, 24, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_44 (Conv2D)              │ (None, 10, 10, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 10, 10, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 1024)           │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 157,433 (614.97 KB)
#  Trainable params: 157,185 (614.00 KB)
#  Non-trainable params: 248 (992.00 B)

# %% [markdown]
# Put the model together:

# %%
# Dr. Tanner's 

inputs = tf.keras.Input(shape=(224,224, 3))
x = image_preprocess(inputs)
outputs = nnet_layers(x)
model = tf.keras.Model(inputs, outputs)
model.summary()

# Mine

outputs2 = nnet_layers2(x)
model2 = tf.keras.Model(inputs, outputs2)
model2.summary()

outputs3 = nnet_layers3(x)
model3 = tf.keras.Model(inputs, outputs3)
model3.summary()
# Out:
# Model: "functional_71"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_8 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_9 (Sequential)       │ (None, 1)              │     1,729,801 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,729,801 (6.60 MB)
#  Trainable params: 1,729,801 (6.60 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_73"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_8 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_10 (Sequential)      │ (None, 1)              │     1,729,801 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,729,801 (6.60 MB)
#  Trainable params: 1,729,801 (6.60 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_75"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_8 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_11 (Sequential)      │ (None, 1)              │       157,433 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 157,433 (614.97 KB)
#  Trainable params: 157,185 (614.00 KB)
#  Non-trainable params: 248 (992.00 B)

# %% [markdown]
# Compile the model:

# %%
metrics = [tf.keras.metrics.BinaryAccuracy(threshold=0.5, name='accuracy'),
           tf.keras.metrics.AUC(),
           tf.keras.metrics.TruePositives(),
           tf.keras.metrics.TrueNegatives(),
           tf.keras.metrics.FalsePositives(),
           tf.keras.metrics.FalseNegatives()
          ]

model.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=metrics)

# Mine

model2.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=metrics)

model3.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=metrics)

# %% [markdown]
# ## Step 4 - Train the Model
#
# Time for some popcorn

# %%
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience=15, monitor='val_loss')

#model.fit(train_dataset, epochs=100,
#         validation_data=val_dataset,
#          callbacks=[es])

#model2.fit(train_dataset, epochs=100,
#         validation_data=val_dataset,
#          callbacks=[es])

model2.fit(train_dataset, epochs=100,
         validation_data=val_dataset,
          callbacks=[es])
# Out:
# Epoch 1/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.5522 - auc_3: 0.4998 - false_negatives_3: 3.0000 - false_positives_3: 314.7046 - loss: 0.6901 - true_negatives_3: 0.0000e+00 - true_positives_3: 393.9318 - val_accuracy: 0.5710 - val_auc_3: 0.7370 - val_false_negatives_3: 0.0000e+00 - val_false_positives_3: 148.0000 - val_loss: 0.6466 - val_true_negatives_3: 0.0000e+00 - val_true_positives_3: 197.0000
# Epoch 2/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 109ms/step - accuracy: 0.5638 - auc_3: 0.6038 - false_negatives_3: 8.7727 - false_positives_3: 299.8636 - loss: 0.6839 - true_negatives_3: 13.0227 - true_positives_3: 389.9773 - val_accuracy: 0.5710 - val_auc_3: 0.5717 - val_false_negatives_3: 0.0000e+00 - val_false_positives_3: 148.0000 - val_loss: 0.6874 - val_true_negatives_3: 0.0000e+00 - val_true_positives_3: 197.0000
# Epoch 3/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 90ms/step - accuracy: 0.5579 - auc_3: 0.4939 - false_negatives_3: 0.9773 - false_positives_3: 313.7273 - loss: 0.6893 - true_negatives_3: 1.8182 - true_positives_3: 395.1136 - val_accuracy: 0.5768 - val_auc_3: 0.6489 - val_false_negatives_3: 2.0000 - val_false_positives_3: 144.0000 - val_loss: 0.6736 - val_true_negatives_3: 4.0000 - val_true_positives_3: 195.0000
# Epoch 4/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 87ms/step - accuracy: 0.5646 - auc_3: 0.5903 - false_negatives_3: 71.2386 - false_positives_3: 227.9773 - loss: 0.6748 - true_negatives_3: 85.5682 - true_positives_3: 326.8523 - val_accuracy: 0.4638 - val_auc_3: 0.6313 - val_false_negatives_3: 183.0000 - val_false_positives_3: 2.0000 - val_loss: 0.7261 - val_true_negatives_3: 146.0000 - val_true_positives_3: 14.0000
# Epoch 5/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.5611 - auc_3: 0.5668 - false_negatives_3: 55.4091 - false_positives_3: 254.5682 - loss: 0.6829 - true_negatives_3: 59.9886 - true_positives_3: 341.6704 - val_accuracy: 0.5449 - val_auc_3: 0.6918 - val_false_negatives_3: 149.0000 - val_false_positives_3: 8.0000 - val_loss: 0.6782 - val_true_negatives_3: 140.0000 - val_true_positives_3: 48.0000
# Epoch 6/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 91ms/step - accuracy: 0.5745 - auc_3: 0.6453 - false_negatives_3: 82.3182 - false_positives_3: 206.8068 - loss: 0.6606 - true_negatives_3: 110.0795 - true_positives_3: 312.4318 - val_accuracy: 0.7014 - val_auc_3: 0.8211 - val_false_negatives_3: 15.0000 - val_false_positives_3: 88.0000 - val_loss: 0.6125 - val_true_negatives_3: 60.0000 - val_true_positives_3: 182.0000
# Epoch 7/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.7539 - auc_3: 0.8037 - false_negatives_3: 91.1591 - false_positives_3: 79.8523 - loss: 0.5634 - true_negatives_3: 236.3409 - true_positives_3: 304.2841 - val_accuracy: 0.7884 - val_auc_3: 0.8468 - val_false_negatives_3: 32.0000 - val_false_positives_3: 41.0000 - val_loss: 0.5003 - val_true_negatives_3: 107.0000 - val_true_positives_3: 165.0000
# Epoch 8/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 88ms/step - accuracy: 0.7685 - auc_3: 0.8255 - false_negatives_3: 76.5341 - false_positives_3: 87.0000 - loss: 0.5129 - true_negatives_3: 228.9659 - true_positives_3: 319.1364 - val_accuracy: 0.7913 - val_auc_3: 0.8653 - val_false_negatives_3: 32.0000 - val_false_positives_3: 40.0000 - val_loss: 0.4668 - val_true_negatives_3: 108.0000 - val_true_positives_3: 165.0000
# Epoch 9/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.7761 - auc_3: 0.8460 - false_negatives_3: 68.1136 - false_positives_3: 91.0000 - loss: 0.4941 - true_negatives_3: 224.0114 - true_positives_3: 328.5114 - val_accuracy: 0.7971 - val_auc_3: 0.8770 - val_false_negatives_3: 37.0000 - val_false_positives_3: 33.0000 - val_loss: 0.4502 - val_true_negatives_3: 115.0000 - val_true_positives_3: 160.0000
# Epoch 10/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 91ms/step - accuracy: 0.8019 - auc_3: 0.8693 - false_negatives_3: 63.3750 - false_positives_3: 76.8068 - loss: 0.4633 - true_negatives_3: 237.3182 - true_positives_3: 334.1364 - val_accuracy: 0.7942 - val_auc_3: 0.8702 - val_false_negatives_3: 27.0000 - val_false_positives_3: 44.0000 - val_loss: 0.4656 - val_true_negatives_3: 104.0000 - val_true_positives_3: 170.0000
# Epoch 11/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.7963 - auc_3: 0.8844 - false_negatives_3: 42.0000 - false_positives_3: 108.3295 - loss: 0.4351 - true_negatives_3: 206.3523 - true_positives_3: 354.9546 - val_accuracy: 0.7971 - val_auc_3: 0.8595 - val_false_negatives_3: 25.0000 - val_false_positives_3: 45.0000 - val_loss: 0.4755 - val_true_negatives_3: 103.0000 - val_true_positives_3: 172.0000
# Epoch 12/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.7919 - auc_3: 0.8824 - false_negatives_3: 48.8409 - false_positives_3: 97.8295 - loss: 0.4356 - true_negatives_3: 218.1591 - true_positives_3: 346.8068 - val_accuracy: 0.7942 - val_auc_3: 0.8654 - val_false_negatives_3: 22.0000 - val_false_positives_3: 49.0000 - val_loss: 0.4577 - val_true_negatives_3: 99.0000 - val_true_positives_3: 175.0000
# Epoch 13/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7980 - auc_3: 0.8881 - false_negatives_3: 43.8068 - false_positives_3: 96.8068 - loss: 0.4275 - true_negatives_3: 217.9432 - true_positives_3: 353.0796 - val_accuracy: 0.8000 - val_auc_3: 0.8860 - val_false_negatives_3: 24.0000 - val_false_positives_3: 45.0000 - val_loss: 0.4266 - val_true_negatives_3: 103.0000 - val_true_positives_3: 173.0000
# Epoch 14/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.8048 - auc_3: 0.8788 - false_negatives_3: 48.4773 - false_positives_3: 89.5455 - loss: 0.4476 - true_negatives_3: 226.2841 - true_positives_3: 347.3296 - val_accuracy: 0.8203 - val_auc_3: 0.8867 - val_false_negatives_3: 26.0000 - val_false_positives_3: 36.0000 - val_loss: 0.4360 - val_true_negatives_3: 112.0000 - val_true_positives_3: 171.0000
# Epoch 15/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8356 - auc_3: 0.9095 - false_negatives_3: 41.8636 - false_positives_3: 79.6250 - loss: 0.3950 - true_negatives_3: 234.9091 - true_positives_3: 355.2386 - val_accuracy: 0.8232 - val_auc_3: 0.8867 - val_false_negatives_3: 27.0000 - val_false_positives_3: 34.0000 - val_loss: 0.4292 - val_true_negatives_3: 114.0000 - val_true_positives_3: 170.0000
# Epoch 16/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8323 - auc_3: 0.9075 - false_negatives_3: 53.3864 - false_positives_3: 68.6932 - loss: 0.3909 - true_negatives_3: 245.8977 - true_positives_3: 343.6591 - val_accuracy: 0.8290 - val_auc_3: 0.9004 - val_false_negatives_3: 26.0000 - val_false_positives_3: 33.0000 - val_loss: 0.4063 - val_true_negatives_3: 115.0000 - val_true_positives_3: 171.0000
# Epoch 17/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8359 - auc_3: 0.9110 - false_negatives_3: 40.6591 - false_positives_3: 74.8068 - loss: 0.3824 - true_negatives_3: 239.6705 - true_positives_3: 356.5000 - val_accuracy: 0.8145 - val_auc_3: 0.9026 - val_false_negatives_3: 35.0000 - val_false_positives_3: 29.0000 - val_loss: 0.4239 - val_true_negatives_3: 119.0000 - val_true_positives_3: 162.0000
# Epoch 18/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8390 - auc_3: 0.9178 - false_negatives_3: 43.2159 - false_positives_3: 69.9091 - loss: 0.3639 - true_negatives_3: 245.1477 - true_positives_3: 353.3636 - val_accuracy: 0.7942 - val_auc_3: 0.8932 - val_false_negatives_3: 39.0000 - val_false_positives_3: 32.0000 - val_loss: 0.4202 - val_true_negatives_3: 116.0000 - val_true_positives_3: 158.0000
# Epoch 19/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8406 - auc_3: 0.9189 - false_negatives_3: 54.4091 - false_positives_3: 62.9545 - loss: 0.3655 - true_negatives_3: 249.9318 - true_positives_3: 344.3409 - val_accuracy: 0.8261 - val_auc_3: 0.9084 - val_false_negatives_3: 31.0000 - val_false_positives_3: 29.0000 - val_loss: 0.3996 - val_true_negatives_3: 119.0000 - val_true_positives_3: 166.0000
# Epoch 20/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8579 - auc_3: 0.9247 - false_negatives_3: 39.9886 - false_positives_3: 66.2841 - loss: 0.3506 - true_negatives_3: 248.5568 - true_positives_3: 356.8068 - val_accuracy: 0.8261 - val_auc_3: 0.9071 - val_false_negatives_3: 27.0000 - val_false_positives_3: 33.0000 - val_loss: 0.3847 - val_true_negatives_3: 115.0000 - val_true_positives_3: 170.0000
# Epoch 21/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8574 - auc_3: 0.9144 - false_negatives_3: 47.3409 - false_positives_3: 53.8068 - loss: 0.3736 - true_negatives_3: 261.8409 - true_positives_3: 348.6477 - val_accuracy: 0.8029 - val_auc_3: 0.9016 - val_false_negatives_3: 47.0000 - val_false_positives_3: 21.0000 - val_loss: 0.4346 - val_true_negatives_3: 127.0000 - val_true_positives_3: 150.0000
# Epoch 22/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.8285 - auc_3: 0.9156 - false_negatives_3: 51.0227 - false_positives_3: 68.1932 - loss: 0.3773 - true_negatives_3: 243.9659 - true_positives_3: 348.4546 - val_accuracy: 0.8232 - val_auc_3: 0.9147 - val_false_negatives_3: 28.0000 - val_false_positives_3: 33.0000 - val_loss: 0.3697 - val_true_negatives_3: 115.0000 - val_true_positives_3: 169.0000
# Epoch 23/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.8520 - auc_3: 0.9278 - false_negatives_3: 44.0000 - false_positives_3: 65.7159 - loss: 0.3487 - true_negatives_3: 251.2500 - true_positives_3: 350.6704 - val_accuracy: 0.8145 - val_auc_3: 0.9209 - val_false_negatives_3: 35.0000 - val_false_positives_3: 29.0000 - val_loss: 0.3764 - val_true_negatives_3: 119.0000 - val_true_positives_3: 162.0000
# Epoch 24/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.8641 - auc_3: 0.9260 - false_negatives_3: 46.7273 - false_positives_3: 56.3182 - loss: 0.3436 - true_negatives_3: 258.5000 - true_positives_3: 350.0909 - val_accuracy: 0.8377 - val_auc_3: 0.9174 - val_false_negatives_3: 26.0000 - val_false_positives_3: 30.0000 - val_loss: 0.3696 - val_true_negatives_3: 118.0000 - val_true_positives_3: 171.0000
# Epoch 25/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.8656 - auc_3: 0.9318 - false_negatives_3: 43.7159 - false_positives_3: 58.1136 - loss: 0.3355 - true_negatives_3: 256.0227 - true_positives_3: 353.7841 - val_accuracy: 0.7884 - val_auc_3: 0.9087 - val_false_negatives_3: 55.0000 - val_false_positives_3: 18.0000 - val_loss: 0.4223 - val_true_negatives_3: 130.0000 - val_true_positives_3: 142.0000
# Epoch 26/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.8543 - auc_3: 0.9273 - false_negatives_3: 52.5909 - false_positives_3: 51.8977 - loss: 0.3471 - true_negatives_3: 262.7500 - true_positives_3: 344.3977 - val_accuracy: 0.8058 - val_auc_3: 0.9207 - val_false_negatives_3: 54.0000 - val_false_positives_3: 13.0000 - val_loss: 0.4391 - val_true_negatives_3: 135.0000 - val_true_positives_3: 143.0000
# Epoch 27/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.8533 - auc_3: 0.9316 - false_negatives_3: 57.4773 - false_positives_3: 48.1477 - loss: 0.3372 - true_negatives_3: 264.9318 - true_positives_3: 341.0796 - val_accuracy: 0.8290 - val_auc_3: 0.9140 - val_false_negatives_3: 25.0000 - val_false_positives_3: 34.0000 - val_loss: 0.3806 - val_true_negatives_3: 114.0000 - val_true_positives_3: 172.0000
# Epoch 28/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.8698 - auc_3: 0.9313 - false_negatives_3: 47.0000 - false_positives_3: 49.4205 - loss: 0.3298 - true_negatives_3: 269.0909 - true_positives_3: 346.1250 - val_accuracy: 0.8377 - val_auc_3: 0.9190 - val_false_negatives_3: 29.0000 - val_false_positives_3: 27.0000 - val_loss: 0.3607 - val_true_negatives_3: 121.0000 - val_true_positives_3: 168.0000
# Epoch 29/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.8678 - auc_3: 0.9294 - false_negatives_3: 43.2955 - false_positives_3: 56.5795 - loss: 0.3407 - true_negatives_3: 258.1818 - true_positives_3: 353.5796 - val_accuracy: 0.8435 - val_auc_3: 0.9221 - val_false_negatives_3: 35.0000 - val_false_positives_3: 19.0000 - val_loss: 0.3755 - val_true_negatives_3: 129.0000 - val_true_positives_3: 162.0000
# Epoch 30/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.8660 - auc_3: 0.9294 - false_negatives_3: 41.3068 - false_positives_3: 53.5455 - loss: 0.3387 - true_negatives_3: 260.8182 - true_positives_3: 355.9659 - val_accuracy: 0.8348 - val_auc_3: 0.9200 - val_false_negatives_3: 40.0000 - val_false_positives_3: 17.0000 - val_loss: 0.3842 - val_true_negatives_3: 131.0000 - val_true_positives_3: 157.0000
# Epoch 31/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8629 - auc_3: 0.9286 - false_negatives_3: 52.2500 - false_positives_3: 47.7273 - loss: 0.3396 - true_negatives_3: 267.6364 - true_positives_3: 344.0227 - val_accuracy: 0.8377 - val_auc_3: 0.9135 - val_false_negatives_3: 28.0000 - val_false_positives_3: 28.0000 - val_loss: 0.3828 - val_true_negatives_3: 120.0000 - val_true_positives_3: 169.0000
# Epoch 32/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8817 - auc_3: 0.9378 - false_negatives_3: 39.8864 - false_positives_3: 49.2273 - loss: 0.3121 - true_negatives_3: 263.5568 - true_positives_3: 358.9659 - val_accuracy: 0.8406 - val_auc_3: 0.9290 - val_false_negatives_3: 33.0000 - val_false_positives_3: 22.0000 - val_loss: 0.3520 - val_true_negatives_3: 126.0000 - val_true_positives_3: 164.0000
# Epoch 33/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.8770 - auc_3: 0.9340 - false_negatives_3: 43.7273 - false_positives_3: 43.2614 - loss: 0.3295 - true_negatives_3: 275.0568 - true_positives_3: 349.5909 - val_accuracy: 0.8551 - val_auc_3: 0.9190 - val_false_negatives_3: 31.0000 - val_false_positives_3: 19.0000 - val_loss: 0.3720 - val_true_negatives_3: 129.0000 - val_true_positives_3: 166.0000
# Epoch 34/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.8680 - auc_3: 0.9401 - false_negatives_3: 41.6932 - false_positives_3: 52.2727 - loss: 0.3110 - true_negatives_3: 259.6818 - true_positives_3: 357.9886 - val_accuracy: 0.8493 - val_auc_3: 0.9267 - val_false_negatives_3: 38.0000 - val_false_positives_3: 14.0000 - val_loss: 0.3585 - val_true_negatives_3: 134.0000 - val_true_positives_3: 159.0000
# Epoch 35/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.8825 - auc_3: 0.9354 - false_negatives_3: 47.3409 - false_positives_3: 41.1136 - loss: 0.3236 - true_negatives_3: 268.2386 - true_positives_3: 354.9432 - val_accuracy: 0.8406 - val_auc_3: 0.9234 - val_false_negatives_3: 28.0000 - val_false_positives_3: 27.0000 - val_loss: 0.3508 - val_true_negatives_3: 121.0000 - val_true_positives_3: 169.0000
# Epoch 36/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.8773 - auc_3: 0.9427 - false_negatives_3: 46.4091 - false_positives_3: 42.7273 - loss: 0.3058 - true_negatives_3: 272.4546 - true_positives_3: 350.0454 - val_accuracy: 0.8406 - val_auc_3: 0.9320 - val_false_negatives_3: 44.0000 - val_false_positives_3: 11.0000 - val_loss: 0.3679 - val_true_negatives_3: 137.0000 - val_true_positives_3: 153.0000
# Epoch 37/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.8680 - auc_3: 0.9396 - false_negatives_3: 48.0909 - false_positives_3: 46.9432 - loss: 0.3156 - true_negatives_3: 269.1023 - true_positives_3: 347.5000 - val_accuracy: 0.8580 - val_auc_3: 0.9321 - val_false_negatives_3: 23.0000 - val_false_positives_3: 26.0000 - val_loss: 0.3308 - val_true_negatives_3: 122.0000 - val_true_positives_3: 174.0000
# Epoch 38/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.8720 - auc_3: 0.9379 - false_negatives_3: 46.1250 - false_positives_3: 46.2614 - loss: 0.3164 - true_negatives_3: 270.1136 - true_positives_3: 349.1364 - val_accuracy: 0.8493 - val_auc_3: 0.9374 - val_false_negatives_3: 22.0000 - val_false_positives_3: 30.0000 - val_loss: 0.3270 - val_true_negatives_3: 118.0000 - val_true_positives_3: 175.0000
# Epoch 39/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.8827 - auc_3: 0.9485 - false_negatives_3: 38.7045 - false_positives_3: 46.0455 - loss: 0.2890 - true_negatives_3: 270.6250 - true_positives_3: 356.2614 - val_accuracy: 0.8551 - val_auc_3: 0.9352 - val_false_negatives_3: 31.0000 - val_false_positives_3: 19.0000 - val_loss: 0.3274 - val_true_negatives_3: 129.0000 - val_true_positives_3: 166.0000
# Epoch 40/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8871 - auc_3: 0.9468 - false_negatives_3: 44.6250 - false_positives_3: 40.3182 - loss: 0.2953 - true_negatives_3: 275.7386 - true_positives_3: 350.9546 - val_accuracy: 0.8580 - val_auc_3: 0.9283 - val_false_negatives_3: 20.0000 - val_false_positives_3: 29.0000 - val_loss: 0.3483 - val_true_negatives_3: 119.0000 - val_true_positives_3: 177.0000
# Epoch 41/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8882 - auc_3: 0.9483 - false_negatives_3: 39.2500 - false_positives_3: 42.6591 - loss: 0.2884 - true_negatives_3: 272.0114 - true_positives_3: 357.7159 - val_accuracy: 0.8725 - val_auc_3: 0.9413 - val_false_negatives_3: 23.0000 - val_false_positives_3: 21.0000 - val_loss: 0.3132 - val_true_negatives_3: 127.0000 - val_true_positives_3: 174.0000
# Epoch 42/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8823 - auc_3: 0.9487 - false_negatives_3: 46.7500 - false_positives_3: 42.8409 - loss: 0.2858 - true_negatives_3: 273.2046 - true_positives_3: 348.8409 - val_accuracy: 0.8667 - val_auc_3: 0.9388 - val_false_negatives_3: 31.0000 - val_false_positives_3: 15.0000 - val_loss: 0.3271 - val_true_negatives_3: 133.0000 - val_true_positives_3: 166.0000
# Epoch 43/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.8666 - auc_3: 0.9352 - false_negatives_3: 49.2159 - false_positives_3: 40.4545 - loss: 0.3244 - true_negatives_3: 273.5796 - true_positives_3: 348.3864 - val_accuracy: 0.8667 - val_auc_3: 0.9375 - val_false_negatives_3: 26.0000 - val_false_positives_3: 20.0000 - val_loss: 0.3224 - val_true_negatives_3: 128.0000 - val_true_positives_3: 171.0000
# Epoch 44/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8968 - auc_3: 0.9461 - false_negatives_3: 39.3295 - false_positives_3: 35.6818 - loss: 0.2890 - true_negatives_3: 278.1364 - true_positives_3: 358.4886 - val_accuracy: 0.8493 - val_auc_3: 0.9324 - val_false_negatives_3: 35.0000 - val_false_positives_3: 17.0000 - val_loss: 0.3559 - val_true_negatives_3: 131.0000 - val_true_positives_3: 162.0000
# Epoch 45/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8839 - auc_3: 0.9438 - false_negatives_3: 43.8182 - false_positives_3: 42.5795 - loss: 0.3096 - true_negatives_3: 272.5227 - true_positives_3: 352.7159 - val_accuracy: 0.8725 - val_auc_3: 0.9434 - val_false_negatives_3: 29.0000 - val_false_positives_3: 15.0000 - val_loss: 0.3080 - val_true_negatives_3: 133.0000 - val_true_positives_3: 168.0000
# Epoch 46/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8832 - auc_3: 0.9551 - false_negatives_3: 40.8068 - false_positives_3: 40.7273 - loss: 0.2778 - true_negatives_3: 276.4886 - true_positives_3: 353.6136 - val_accuracy: 0.8551 - val_auc_3: 0.9405 - val_false_negatives_3: 33.0000 - val_false_positives_3: 17.0000 - val_loss: 0.3205 - val_true_negatives_3: 131.0000 - val_true_positives_3: 164.0000
# Epoch 47/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8975 - auc_3: 0.9543 - false_negatives_3: 40.0227 - false_positives_3: 36.0568 - loss: 0.2683 - true_negatives_3: 282.6704 - true_positives_3: 352.8864 - val_accuracy: 0.8725 - val_auc_3: 0.9441 - val_false_negatives_3: 18.0000 - val_false_positives_3: 26.0000 - val_loss: 0.3014 - val_true_negatives_3: 122.0000 - val_true_positives_3: 179.0000
# Epoch 48/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8853 - auc_3: 0.9553 - false_negatives_3: 36.3864 - false_positives_3: 46.1136 - loss: 0.2723 - true_negatives_3: 267.8068 - true_positives_3: 361.3296 - val_accuracy: 0.8667 - val_auc_3: 0.9408 - val_false_negatives_3: 33.0000 - val_false_positives_3: 13.0000 - val_loss: 0.3251 - val_true_negatives_3: 135.0000 - val_true_positives_3: 164.0000
# Epoch 49/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8974 - auc_3: 0.9559 - false_negatives_3: 34.3182 - false_positives_3: 39.3750 - loss: 0.2641 - true_negatives_3: 274.6932 - true_positives_3: 363.2500 - val_accuracy: 0.8667 - val_auc_3: 0.9458 - val_false_negatives_3: 24.0000 - val_false_positives_3: 22.0000 - val_loss: 0.2967 - val_true_negatives_3: 126.0000 - val_true_positives_3: 173.0000
# Epoch 50/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8828 - auc_3: 0.9507 - false_negatives_3: 41.8864 - false_positives_3: 41.1591 - loss: 0.2818 - true_negatives_3: 273.7614 - true_positives_3: 354.8296 - val_accuracy: 0.8812 - val_auc_3: 0.9471 - val_false_negatives_3: 18.0000 - val_false_positives_3: 23.0000 - val_loss: 0.3127 - val_true_negatives_3: 125.0000 - val_true_positives_3: 179.0000
# Epoch 51/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8972 - auc_3: 0.9549 - false_negatives_3: 41.3182 - false_positives_3: 37.8750 - loss: 0.2734 - true_negatives_3: 275.9432 - true_positives_3: 356.5000 - val_accuracy: 0.8696 - val_auc_3: 0.9472 - val_false_negatives_3: 25.0000 - val_false_positives_3: 20.0000 - val_loss: 0.2973 - val_true_negatives_3: 128.0000 - val_true_positives_3: 172.0000
# Epoch 52/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9020 - auc_3: 0.9638 - false_negatives_3: 37.5455 - false_positives_3: 32.5682 - loss: 0.2471 - true_negatives_3: 285.5114 - true_positives_3: 356.0114 - val_accuracy: 0.8696 - val_auc_3: 0.9489 - val_false_negatives_3: 23.0000 - val_false_positives_3: 22.0000 - val_loss: 0.2868 - val_true_negatives_3: 126.0000 - val_true_positives_3: 174.0000
# Epoch 53/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9120 - auc_3: 0.9664 - false_negatives_3: 37.5568 - false_positives_3: 28.4886 - loss: 0.2344 - true_negatives_3: 285.8409 - true_positives_3: 359.7500 - val_accuracy: 0.8609 - val_auc_3: 0.9385 - val_false_negatives_3: 20.0000 - val_false_positives_3: 28.0000 - val_loss: 0.3309 - val_true_negatives_3: 120.0000 - val_true_positives_3: 177.0000
# Epoch 54/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8991 - auc_3: 0.9644 - false_negatives_3: 34.1818 - false_positives_3: 35.7955 - loss: 0.2421 - true_negatives_3: 278.9432 - true_positives_3: 362.7159 - val_accuracy: 0.8812 - val_auc_3: 0.9528 - val_false_negatives_3: 29.0000 - val_false_positives_3: 12.0000 - val_loss: 0.2959 - val_true_negatives_3: 136.0000 - val_true_positives_3: 168.0000
# Epoch 55/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8914 - auc_3: 0.9645 - false_negatives_3: 41.0114 - false_positives_3: 36.4886 - loss: 0.2429 - true_negatives_3: 280.7954 - true_positives_3: 353.3409 - val_accuracy: 0.8841 - val_auc_3: 0.9498 - val_false_negatives_3: 19.0000 - val_false_positives_3: 21.0000 - val_loss: 0.2987 - val_true_negatives_3: 127.0000 - val_true_positives_3: 178.0000
# Epoch 56/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8988 - auc_3: 0.9588 - false_negatives_3: 38.5455 - false_positives_3: 35.5227 - loss: 0.2565 - true_negatives_3: 280.1477 - true_positives_3: 357.4204 - val_accuracy: 0.8870 - val_auc_3: 0.9496 - val_false_negatives_3: 18.0000 - val_false_positives_3: 21.0000 - val_loss: 0.3039 - val_true_negatives_3: 127.0000 - val_true_positives_3: 179.0000
# Epoch 57/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.9030 - auc_3: 0.9648 - false_negatives_3: 34.5682 - false_positives_3: 37.7159 - loss: 0.2325 - true_negatives_3: 276.4886 - true_positives_3: 362.8636 - val_accuracy: 0.8928 - val_auc_3: 0.9550 - val_false_negatives_3: 21.0000 - val_false_positives_3: 16.0000 - val_loss: 0.2800 - val_true_negatives_3: 132.0000 - val_true_positives_3: 176.0000
# Epoch 58/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9224 - auc_3: 0.9746 - false_negatives_3: 32.0682 - false_positives_3: 29.8409 - loss: 0.1999 - true_negatives_3: 286.3182 - true_positives_3: 363.4091 - val_accuracy: 0.8899 - val_auc_3: 0.9534 - val_false_negatives_3: 19.0000 - val_false_positives_3: 19.0000 - val_loss: 0.2861 - val_true_negatives_3: 129.0000 - val_true_positives_3: 178.0000
# Epoch 59/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 92ms/step - accuracy: 0.8897 - auc_3: 0.9602 - false_negatives_3: 41.0795 - false_positives_3: 35.7841 - loss: 0.2486 - true_negatives_3: 280.2500 - true_positives_3: 354.5227 - val_accuracy: 0.8667 - val_auc_3: 0.9449 - val_false_negatives_3: 28.0000 - val_false_positives_3: 18.0000 - val_loss: 0.3099 - val_true_negatives_3: 130.0000 - val_true_positives_3: 169.0000
# Epoch 60/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.8983 - auc_3: 0.9635 - false_negatives_3: 39.6477 - false_positives_3: 37.1250 - loss: 0.2449 - true_negatives_3: 276.4886 - true_positives_3: 358.3750 - val_accuracy: 0.9043 - val_auc_3: 0.9554 - val_false_negatives_3: 22.0000 - val_false_positives_3: 11.0000 - val_loss: 0.2801 - val_true_negatives_3: 137.0000 - val_true_positives_3: 175.0000
# Epoch 61/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8960 - auc_3: 0.9616 - false_negatives_3: 40.1023 - false_positives_3: 34.5455 - loss: 0.2451 - true_negatives_3: 282.1932 - true_positives_3: 354.7954 - val_accuracy: 0.8725 - val_auc_3: 0.9468 - val_false_negatives_3: 26.0000 - val_false_positives_3: 18.0000 - val_loss: 0.2997 - val_true_negatives_3: 130.0000 - val_true_positives_3: 171.0000
# Epoch 62/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9252 - auc_3: 0.9743 - false_negatives_3: 30.7159 - false_positives_3: 25.6250 - loss: 0.2006 - true_negatives_3: 290.1250 - true_positives_3: 365.1704 - val_accuracy: 0.8812 - val_auc_3: 0.9551 - val_false_negatives_3: 29.0000 - val_false_positives_3: 12.0000 - val_loss: 0.2877 - val_true_negatives_3: 136.0000 - val_true_positives_3: 168.0000
# Epoch 63/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9143 - auc_3: 0.9722 - false_negatives_3: 33.6136 - false_positives_3: 31.7955 - loss: 0.2084 - true_negatives_3: 282.7159 - true_positives_3: 363.5114 - val_accuracy: 0.8783 - val_auc_3: 0.9453 - val_false_negatives_3: 28.0000 - val_false_positives_3: 14.0000 - val_loss: 0.3095 - val_true_negatives_3: 134.0000 - val_true_positives_3: 169.0000
# Epoch 64/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9027 - auc_3: 0.9631 - false_negatives_3: 35.4659 - false_positives_3: 35.1818 - loss: 0.2443 - true_negatives_3: 281.0227 - true_positives_3: 359.9659 - val_accuracy: 0.8899 - val_auc_3: 0.9528 - val_false_negatives_3: 24.0000 - val_false_positives_3: 14.0000 - val_loss: 0.2802 - val_true_negatives_3: 134.0000 - val_true_positives_3: 173.0000
# Epoch 65/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9091 - auc_3: 0.9686 - false_negatives_3: 32.5341 - false_positives_3: 31.5682 - loss: 0.2274 - true_negatives_3: 281.9091 - true_positives_3: 365.6250 - val_accuracy: 0.8841 - val_auc_3: 0.9496 - val_false_negatives_3: 24.0000 - val_false_positives_3: 16.0000 - val_loss: 0.2983 - val_true_negatives_3: 132.0000 - val_true_positives_3: 173.0000
# Epoch 66/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 8s 87ms/step - accuracy: 0.9140 - auc_3: 0.9704 - false_negatives_3: 30.3409 - false_positives_3: 32.1477 - loss: 0.2125 - true_negatives_3: 281.4886 - true_positives_3: 367.6591 - val_accuracy: 0.8928 - val_auc_3: 0.9554 - val_false_negatives_3: 21.0000 - val_false_positives_3: 16.0000 - val_loss: 0.2759 - val_true_negatives_3: 132.0000 - val_true_positives_3: 176.0000
# Epoch 67/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9244 - auc_3: 0.9764 - false_negatives_3: 32.7386 - false_positives_3: 26.6818 - loss: 0.1948 - true_negatives_3: 289.1704 - true_positives_3: 363.0454 - val_accuracy: 0.8957 - val_auc_3: 0.9523 - val_false_negatives_3: 18.0000 - val_false_positives_3: 18.0000 - val_loss: 0.3059 - val_true_negatives_3: 130.0000 - val_true_positives_3: 179.0000
# Epoch 68/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9114 - auc_3: 0.9713 - false_negatives_3: 34.6023 - false_positives_3: 33.0000 - loss: 0.2129 - true_negatives_3: 282.3636 - true_positives_3: 361.6704 - val_accuracy: 0.8899 - val_auc_3: 0.9518 - val_false_negatives_3: 23.0000 - val_false_positives_3: 15.0000 - val_loss: 0.2983 - val_true_negatives_3: 133.0000 - val_true_positives_3: 174.0000
# Epoch 69/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9301 - auc_3: 0.9775 - false_negatives_3: 31.2386 - false_positives_3: 23.5000 - loss: 0.1875 - true_negatives_3: 288.9886 - true_positives_3: 367.9091 - val_accuracy: 0.8870 - val_auc_3: 0.9522 - val_false_negatives_3: 21.0000 - val_false_positives_3: 18.0000 - val_loss: 0.2999 - val_true_negatives_3: 130.0000 - val_true_positives_3: 176.0000
# Epoch 70/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9090 - auc_3: 0.9695 - false_negatives_3: 37.4886 - false_positives_3: 25.7045 - loss: 0.2274 - true_negatives_3: 286.6023 - true_positives_3: 361.8409 - val_accuracy: 0.8986 - val_auc_3: 0.9488 - val_false_negatives_3: 21.0000 - val_false_positives_3: 14.0000 - val_loss: 0.3358 - val_true_negatives_3: 134.0000 - val_true_positives_3: 176.0000
# Epoch 71/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8943 - auc_3: 0.9683 - false_negatives_3: 39.1136 - false_positives_3: 34.5000 - loss: 0.2277 - true_negatives_3: 279.7841 - true_positives_3: 358.2386 - val_accuracy: 0.8841 - val_auc_3: 0.9495 - val_false_negatives_3: 23.0000 - val_false_positives_3: 17.0000 - val_loss: 0.3189 - val_true_negatives_3: 131.0000 - val_true_positives_3: 174.0000
# Epoch 72/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.9132 - auc_3: 0.9645 - false_negatives_3: 30.4545 - false_positives_3: 32.1477 - loss: 0.2251 - true_negatives_3: 282.1704 - true_positives_3: 366.8636 - val_accuracy: 0.8841 - val_auc_3: 0.9524 - val_false_negatives_3: 24.0000 - val_false_positives_3: 16.0000 - val_loss: 0.3105 - val_true_negatives_3: 132.0000 - val_true_positives_3: 173.0000
# Epoch 73/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9303 - auc_3: 0.9764 - false_negatives_3: 27.3523 - false_positives_3: 25.5455 - loss: 0.1895 - true_negatives_3: 291.1704 - true_positives_3: 367.5682 - val_accuracy: 0.8812 - val_auc_3: 0.9489 - val_false_negatives_3: 17.0000 - val_false_positives_3: 24.0000 - val_loss: 0.3456 - val_true_negatives_3: 124.0000 - val_true_positives_3: 180.0000
# Epoch 74/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9199 - auc_3: 0.9728 - false_negatives_3: 31.2273 - false_positives_3: 26.8523 - loss: 0.2105 - true_negatives_3: 286.4204 - true_positives_3: 367.1364 - val_accuracy: 0.8870 - val_auc_3: 0.9503 - val_false_negatives_3: 21.0000 - val_false_positives_3: 18.0000 - val_loss: 0.3122 - val_true_negatives_3: 130.0000 - val_true_positives_3: 176.0000
# Epoch 75/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9112 - auc_3: 0.9707 - false_negatives_3: 32.9432 - false_positives_3: 28.4091 - loss: 0.2151 - true_negatives_3: 285.0454 - true_positives_3: 365.2386 - val_accuracy: 0.9014 - val_auc_3: 0.9542 - val_false_negatives_3: 15.0000 - val_false_positives_3: 19.0000 - val_loss: 0.3190 - val_true_negatives_3: 129.0000 - val_true_positives_3: 182.0000
# Epoch 76/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - accuracy: 0.9304 - auc_3: 0.9749 - false_negatives_3: 32.6136 - false_positives_3: 20.1136 - loss: 0.1937 - true_negatives_3: 293.3068 - true_positives_3: 365.6023 - val_accuracy: 0.8812 - val_auc_3: 0.9530 - val_false_negatives_3: 21.0000 - val_false_positives_3: 20.0000 - val_loss: 0.3030 - val_true_negatives_3: 128.0000 - val_true_positives_3: 176.0000
# Epoch 77/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9153 - auc_3: 0.9732 - false_negatives_3: 38.5000 - false_positives_3: 24.7955 - loss: 0.2063 - true_negatives_3: 290.4318 - true_positives_3: 357.9091 - val_accuracy: 0.8957 - val_auc_3: 0.9485 - val_false_negatives_3: 20.0000 - val_false_positives_3: 16.0000 - val_loss: 0.3288 - val_true_negatives_3: 132.0000 - val_true_positives_3: 177.0000
# Epoch 78/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.9253 - auc_3: 0.9803 - false_negatives_3: 31.9659 - false_positives_3: 22.5795 - loss: 0.1758 - true_negatives_3: 294.6023 - true_positives_3: 362.4886 - val_accuracy: 0.9014 - val_auc_3: 0.9435 - val_false_negatives_3: 19.0000 - val_false_positives_3: 15.0000 - val_loss: 0.3586 - val_true_negatives_3: 133.0000 - val_true_positives_3: 178.0000
# Epoch 79/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9170 - auc_3: 0.9763 - false_negatives_3: 34.9659 - false_positives_3: 24.7841 - loss: 0.1911 - true_negatives_3: 289.7046 - true_positives_3: 362.1818 - val_accuracy: 0.8870 - val_auc_3: 0.9416 - val_false_negatives_3: 23.0000 - val_false_positives_3: 16.0000 - val_loss: 0.3393 - val_true_negatives_3: 132.0000 - val_true_positives_3: 174.0000
# Epoch 80/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9033 - auc_3: 0.9653 - false_negatives_3: 32.7273 - false_positives_3: 31.6818 - loss: 0.2329 - true_negatives_3: 281.8409 - true_positives_3: 365.3864 - val_accuracy: 0.8899 - val_auc_3: 0.9513 - val_false_negatives_3: 19.0000 - val_false_positives_3: 19.0000 - val_loss: 0.3293 - val_true_negatives_3: 129.0000 - val_true_positives_3: 178.0000
# Epoch 81/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.9238 - auc_3: 0.9749 - false_negatives_3: 32.6477 - false_positives_3: 27.3409 - loss: 0.2011 - true_negatives_3: 287.7386 - true_positives_3: 363.9091 - val_accuracy: 0.8928 - val_auc_3: 0.9523 - val_false_negatives_3: 21.0000 - val_false_positives_3: 16.0000 - val_loss: 0.3135 - val_true_negatives_3: 132.0000 - val_true_positives_3: 176.0000

# %% [markdown]
# ## Step 5 - Save the model
#
# If you like your model, then save your model.

# %%
model2.save('../models/cnn_model_rdf_2024_04_29_model2_fixedmetrics.keras')

# %% [markdown]
# ## Step 6 - Load the model (if necessary)
#
# If you already saved a model, you can load it again.

# %%
model_to_test = tf.keras.models.load_model('../models/cnn_model_rdf_2024_04_29_model2_fixedmetrics.keras')

# %% [markdown]
# ## Step 7 - Test the Model

# %%
# This is the validation set. Notice `shuffle = FALSE` and `subset = validation`
test_set = tf.keras.utils.image_dataset_from_directory(
    '../test/all/',
    class_names = ['not_niblet','niblet'],
    color_mode='rgb',
    batch_size=200,
    image_size=IMAGE_SIZE,
    shuffle=True,
    seed=SEED)

test_iterator = iter(test_set)
test_batch, _ = next(test_iterator)

# Test Shapes

#model_to_test.summary()

#print(test_batch[0].shape)
# Out:
# Found 192 files belonging to 2 classes.

# %%
import matplotlib.pyplot as plt

predictions = model_to_test.predict(test_batch)

plt.figure(figsize=(10,20))
for i in range(50):
    plt.subplot(10,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_batch[i]/255)
    plt.xlabel("{pred:.4f}".format(pred = predictions[i][0]))
plt.show()

model_to_test.evaluate(test_set, return_dict = True)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step - accuracy: 0.7448 - auc_3: 0.9158 - false_negatives_3: 4.0000 - false_positives_3: 45.0000 - loss: 0.5816 - true_negatives_3: 57.0000 - true_positives_3: 86.0000
# {'accuracy': 0.7447916865348816,
#  'auc_3': 0.9157952070236206,
#  'false_negatives_3': 4.0,
#  'false_positives_3': 45.0,
#  'loss': 0.5815778374671936,
#  'true_negatives_3': 57.0,
#  'true_positives_3': 86.0}
